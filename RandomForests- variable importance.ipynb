# %%
import numpy as np
import pandas as pd
from sklearn.datasets import load_diabetes
from sklearn.inspection import permutation_importance
from matplotlib import pyplot as plt

# Using diabetes dataset as it is has all numeric values and it a good dataset for regression

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
diabetes = load_diabetes()

# %%
# diabetes is a array, so i am converting into a df

x = pd.DataFrame(diabetes.data, columns = diabetes.feature_names)
y = diabetes.target

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3)

# %%
rf = RandomForestRegressor(n_estimators=100, bootstrap = True, oob_score= True)

# %%
print(x_train.shape)
# Out:
# (309, 10)

# %%
rf.fit(x_train, y_train)
# Out:
# RandomForestRegressor(oob_score=True)

# %%
rf.feature_importances_
# Out:
# array([0.06283968, 0.01208527, 0.26744557, 0.11206841, 0.05284312,
#        0.06379153, 0.06348235, 0.04064247, 0.24688266, 0.07791893])

# %%
plt.bar(diabetes.feature_names, rf.feature_importances_)
# Out:
# <BarContainer object of 10 artists>

# %%
# Lets beautify of our plot
sorted_features = rf.feature_importances_.argsort()
plt.barh(boston.feature_names[sorted_features], rf.feature_importances_[sorted_features])
plt.xlabel("Random Forest Feature Importance")
# Out:
# Text(0.5, 0, 'Random Forest Feature Importance')
